# %% [markdown]
# # Personal Finance Analyzer

# %% [markdown]
# ## Milestone 1: Basic Transaction Logic

# %%
# Milestone 1 starter code
# 1. Create a variable for a starting bank balance
# 2. Create a variable for an income amount
# 3. Create a variable for an expense amount
# 4. Calculate the ending balance by adding income and subtracting the expense
# 5. Print a report that shows:
#    - Starting balance: 
#    - Income Amount:
#    - Expense Amount:
#    - Ending balance:
